# %% [markdown]
# # Python Basics

# %% [markdown]
# ## Variables and Data Tyeps

# %%
x=5
x
# Out:
# 5

# %%
x+2
# Out:
# 7

# %%
x-2
# Out:
# 3

# %%
x*2
# Out:
# 10

# %%
x**2
# Out:
# 25

# %%
x/2
# Out:
# 2.5

# %% [markdown]
# ## String

# %%
my_string='thisStringIsAwesome'
my_string
# Out:
# 'thisStringIsAwesome'

# %%
my_string*2
# Out:
# 'thisStringIsAwesomethisStringIsAwesome'

# %%
my_string+'Innit'
# Out:
# 'thisStringIsAwesomeInnit'

# %%
'm' in my_string
# Out:
# True

# %%
my_string[3]
# Out:
# 's'

# %%
my_string[4:9]
# Out:
# 'Strin'

# %%
my_string.upper()
# Out:
# 'THISSTRINGISAWESOME'

# %%
my_string.lower()
# Out:
# 'thisstringisawesome'

# %%
my_string.count('w')
# Out:
# 1

# %%
my_string.replace('e','i')
# Out:
# 'thisStringIsAwisomi'

# %%
my_string.strip()
# Out:
# 'thisStringIsAwesome'

# %%
my_string
# Out:
# 'thisStringIsAwesome'

# %% [markdown]
# ## Lists

# %%
a='is'
b='nice'
my_list=['my','list',a,b]
my_list
# Out:
# ['my', 'list', 'is', 'nice']

# %%
my_list2=[[4,5,6,7],[3,4,5,6]]
my_list2
# Out:
# [[4, 5, 6, 7], [3, 4, 5, 6]]

# %%
my_list[1]
# Out:
# 'list'

# %%
my_list[-3]
# Out:
# 'list'

# %%
my_list[1:3]
# Out:
# ['list', 'is']

# %%
my_list[1:]
# Out:
# ['list', 'is', 'nice']

# %%
my_list[:3]
# Out:
# ['my', 'list', 'is']

# %%
my_list[:]
# Out:
# ['my', 'list', 'is', 'nice']

# %%
my_list2[1][0]
# Out:
# 3

# %%
my_list2[1][:2]
# Out:
# [3, 4]

# %%
my_list+my_list
# Out:
# ['my', 'list', 'is', 'nice', 'my', 'list', 'is', 'nice']

# %%
my_list*2
# Out:
# ['my', 'list', 'is', 'nice', 'my', 'list', 'is', 'nice']

# %%
my_list.index(a)
# Out:
# 2

# %%
my_list.count(a)
# Out:
# 1

# %%
my_list.append('!')
my_list
# Out:
# ['my', 'list', 'is', 'nice', '!']

# %%
my_list.remove('!')
my_list
# Out:
# ['my', 'list', 'is', 'nice']

# %%
del(my_list[0:1])

# %%
my_list
# Out:
# ['list', 'is', 'nice']

# %%
my_list.reverse()

# %%
my_list
# Out:
# ['nice', 'is', 'list']

# %%
my_list.extend('!')
my_list
# Out:
# ['nice', 'is', 'list', '!']

# %%
my_list.pop(-1)
my_list
# Out:
# ['nice', 'is', 'list']

# %%
my_list.insert(0,'!')
my_list
# Out:
# ['!', 'nice', 'is', 'list']

# %%
my_list.sort()
my_list
# Out:
# ['!', 'is', 'list', 'nice']

# %% [markdown]
# ## Libraries

# %%
import numpy as np

# %% [markdown]
# ## Numpy Arrays

# %%
my_list=[1,2,3,4]
my_array=np.array(my_list)
my_array
# Out:
# array([1, 2, 3, 4])

# %%
my_2darray=np.array([[1,2,3],[4,5,6]])
my_2darray
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
my_array[1]
# Out:
# 2

# %%
my_array[0:2]
# Out:
# array([1, 2])

# %%
my_2darray[:,0]
# Out:
# array([1, 4])

# %%
my_array>3
# Out:
# array([False, False, False,  True])

# %%
my_array*2
# Out:
# array([2, 4, 6, 8])

# %%
my_array+np.array([5,6,7,8])
# Out:
# array([ 6,  8, 10, 12])

# %%
my_array
# Out:
# array([1, 2, 3, 4])

# %%
my_array.shape
# Out:
# (4,)

# %%
np.insert(my_array,1,5)
# Out:
# array([1, 5, 2, 3, 4])

# %%
np.delete(my_array,[1])
# Out:
# array([1, 3, 4])

# %%
my_array
# Out:
# array([1, 2, 3, 4])

# %%
np.mean(my_array)
# Out:
# 2.5

# %%
np.median(my_array)
# Out:
# 2.5

# %%
np.std(my_array)
# Out:
# 1.118033988749895

# %% [markdown]
# ## 字典

# %%
empty_dict={}

# %%
empty_dict
# Out:
# {}

# %%
d1

# %% [markdown]
# # Pandas Basics

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Data Structures

# %%
s=pd.Series([3,-5,7,4],index=['a','b','c','d'])
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
data={'Country':['Belgium','India','Brazil'],
     'Capital':['Brussels','New Delhi','Brasilia'],
     'Population':[11190846,1303171035,207847528]}
df=pd.DataFrame(data,columns=['Country','Capital','Population'])
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %% [markdown]
# ## Selection

# %%
s['b']
# Out:
# -5

# %%
df[1:]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasilia   207847528

# %%
df.iloc[0,0]
# Out:
# 'Belgium'

# %%
df.iat[0,0]
# Out:
# 'Belgium'

# %%
df.iat[0,0]
# Out:
# 'Belgium'

# %%
df.loc[[0],['Country']]
# Out:
#    Country
# 0  Belgium

# %%
df.at[0,'Country']
# Out:
# 'Belgium'

# %%
df.ix[2]
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# Country          Brazil
# Capital        Brasilia
# Population    207847528
# Name: 2, dtype: object

# %%
df.ix[:,'Capital']
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# 0     Brussels
# 1    New Delhi
# 2     Brasilia
# Name: Capital, dtype: object

# %%
df.ix[1,'Capital']
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# 'New Delhi'

# %%
df.Capital
# Out:
# 0     Brussels
# 1    New Delhi
# 2     Brasilia
# Name: Capital, dtype: object

# %%
df['Capital']
# Out:
# 0     Brussels
# 1    New Delhi
# 2     Brasilia
# Name: Capital, dtype: object

# %%
df.loc[0,'Country']
# Out:
# 'Belgium'

# %%
df.loc[[0],['Country']]
# Out:
#    Country
# 0  Belgium

# %%
s[~(s>1)]
# Out:
# b   -5
# dtype: int64

# %%
s[(s<-1)|(s>2)]
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
df[df['Population']>1200000000]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035

# %%
s['a']=6

# %%
s
# Out:
# a    6
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# ## Dropping

# %%
s.drop(['a','c'])
# Out:
# b   -5
# d    4
# dtype: int64

# %%
s
# Out:
# a    6
# b   -5
# c    7
# d    4
# dtype: int64

# %%
df.drop('Country',axis=1)
# Out:
#      Capital  Population
# 0   Brussels    11190846
# 1  New Delhi  1303171035
# 2   Brasilia   207847528

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %% [markdown]
# ## Sort and Rank

# %%
df.sort_index()
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
df.sort_values(by='Country')
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 2   Brazil   Brasilia   207847528
# 1    India  New Delhi  1303171035

# %%
df.rank()
# Out:
#    Country  Capital  Population
# 0      1.0      2.0         1.0
# 1      3.0      3.0         3.0
# 2      2.0      1.0         2.0

# %% [markdown]
# ## Retrieving Series/DataFrame Information

# %%
df.shape
# Out:
# (3, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Country', 'Capital', 'Population'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# Country       3 non-null object
# Capital       3 non-null object
# Population    3 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 152.0+ bytes

# %%
df.count()
# Out:
# Country       3
# Capital       3
# Population    3
# dtype: int64

# %%
df.sum()
# Out:
# Country              BelgiumIndiaBrazil
# Capital       BrusselsNew DelhiBrasilia
# Population                   1522209409
# dtype: object

# %%
df.cumsum()
# Out:
#               Country                    Capital  Population
# 0             Belgium                   Brussels    11190846
# 1        BelgiumIndia          BrusselsNew Delhi  1314361881
# 2  BelgiumIndiaBrazil  BrusselsNew DelhiBrasilia  1522209409

# %%
df.min()
# Out:
# Country        Belgium
# Capital       Brasilia
# Population    11190846
# dtype: object

# %%
df.max()
# Out:
# Country            India
# Capital        New Delhi
# Population    1303171035
# dtype: object

# %%
df.describe()
# Out:
#          Population
# count  3.000000e+00
# mean   5.074031e+08
# std    6.961346e+08
# min    1.119085e+07
# 25%    1.095192e+08
# 50%    2.078475e+08
# 75%    7.555093e+08
# max    1.303171e+09

# %%
df.mean()
# Out:
# Population    5.074031e+08
# dtype: float64

# %%
df.median()
# Out:
# Population    207847528.0
# dtype: float64

# %% [markdown]
# ## Applying Functions

# %%
f=lambda x:x*2

# %%
df.apply(f)
# Out:
#           Country             Capital  Population
# 0  BelgiumBelgium    BrusselsBrussels    22381692
# 1      IndiaIndia  New DelhiNew Delhi  2606342070
# 2    BrazilBrazil    BrasiliaBrasilia   415695056

# %%
df.applymap(f)
# Out:
#           Country             Capital  Population
# 0  BelgiumBelgium    BrusselsBrussels    22381692
# 1      IndiaIndia  New DelhiNew Delhi  2606342070
# 2    BrazilBrazil    BrasiliaBrasilia   415695056

# %%
s
# Out:
# a    6
# b   -5
# c    7
# d    4
# dtype: int64

# %%
s3=pd.Series([7,-2,3],index=['a','c','d'])
s3
# Out:
# a    7
# c   -2
# d    3
# dtype: int64

# %%
s+s3
# Out:
# a    13.0
# b     NaN
# c     5.0
# d     7.0
# dtype: float64

# %%
s.add(s3,fill_value=0)
# Out:
# a    13.0
# b    -5.0
# c     5.0
# d     7.0
# dtype: float64

# %%
s.sub(s3,fill_value=2)
# Out:
# a   -1.0
# b   -7.0
# c    9.0
# d    1.0
# dtype: float64

# %%
s.div(s3,fill_value=4)
# Out:
# a    0.857143
# b   -1.250000
# c   -3.500000
# d    1.333333
# dtype: float64

# %%
s.mul(s3,fill_value=3)
# Out:
# a    42.0
# b   -15.0
# c   -14.0
# d    12.0
# dtype: float64

# %% [markdown]
# # Pandas

# %%
from pandas import Series, DataFrame

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
obj=Series([4,7,-5,3])

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2=Series([4,7,-5,3],index=['d','b','a','c'])

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2['a']
# Out:
# -5

# %%
obj2['d']=6

# %%
obj2[['c','a','d']]
# Out:
# c    3
# a   -5
# d    6
# dtype: int64

# %%
obj2
# Out:
# d    6
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2[obj2>0]
# Out:
# d    6
# b    7
# c    3
# dtype: int64

# %%
obj2*2
# Out:
# d    12
# b    14
# a   -10
# c     6
# dtype: int64

# %%
np.exp(obj2)
# Out:
# d     403.428793
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
'b' in obj2
# Out:
# True

# %%
'e' in obj2
# Out:
# False

# %%
sdata={
    'Ohio':35000,
    'Texas':71000,
    'Oregon':16000,
    'Utah':5000
}

# %%
obj3=pd.Series(sdata)

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
states=['California','Ohio','Oregon','Texas']

# %%
obj4=Series(sdata,index=states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj3+obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
obj4.name='population'

# %%
obj4.index.name='state'

# %%
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.index=['Bob','Steve','Jeff','Ryan']

# %%
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -5
# Ryan     3
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
data={
    'state':['Ohio','Ohio','Ohio','Nevada','Nevada'],
    'year':[2000,2001,2002,2001,2002],
    'pop':[1.5,1.7,3.6,2.4,2.9]}
frame=DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
DataFrame(data,columns=['year','state','pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9

# %%
frame2=DataFrame(data,columns=['year','state','pop','debt'],
                index=['one','two','three','four','five'])
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# Name: year, dtype: int64

# %%
frame2.ix['three']
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %%
frame2['debt']=16.5

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5

# %%
frame2['debt']=np.arange(5.)

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   0.0
# two    2001    Ohio  1.7   1.0
# three  2002    Ohio  3.6   2.0
# four   2001  Nevada  2.4   3.0
# five   2002  Nevada  2.9   4.0

# %%
val=Series([-1.2,-1.5,-1.7],index=['two','four','five'])

# %%
frame2['debt']=val

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7

# %%
frame2['eastern']=frame2.state=='Ohio'

# %%
frame2
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7  -1.2     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False

# %%
del frame2['eastern']

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7

# %%
frame2.debt=0

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5     0
# two    2001    Ohio  1.7     0
# three  2002    Ohio  3.6     0
# four   2001  Nevada  2.4     0
# five   2002  Nevada  2.9     0

# %%
pop={
    'Nevada':{2001:2.4,2002:2.9},
    'Ohio':{2000:1.5,2001:1.7,2002:3.6}
}

# %%
frame3=DataFrame(pop)

# %%
frame3
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6

# %%
frame3.T
# Out:
#         2000  2001  2002
# Nevada   NaN   2.4   2.9
# Ohio     1.5   1.7   3.6

# %%
frame3
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6

# %%
pop
# Out:
# {'Nevada': {2001: 2.4, 2002: 2.9}, 'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}

# %%
pdata={'Ohio':frame3['Ohio'][:-1],
      'Nevada':frame3['Nevada'][:2]}

# %%
DataFrame(pdata)
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4

# %%
frame3['Ohio'][:-1]
# Out:
# 2000    1.5
# 2001    1.7
# Name: Ohio, dtype: float64

# %%
frame3['Nevada'][:2]
# Out:
# 2000    NaN
# 2001    2.4
# Name: Nevada, dtype: float64

# %%
frame3
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6

# %%
frame3.index.name='year'

# %%
frame3.columns.name='state'

# %%
frame3
# Out:
# state  Nevada  Ohio
# year
# 2000      NaN   1.5
# 2001      2.4   1.7
# 2002      2.9   3.6

# %%
frame3.values
# Out:
# array([[nan, 1.5],
#        [2.4, 1.7],
#        [2.9, 3.6]])

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5     0
# two    2001    Ohio  1.7     0
# three  2002    Ohio  3.6     0
# four   2001  Nevada  2.4     0
# five   2002  Nevada  2.9     0

# %%
frame2.values
# Out:
# array([[2000, 'Ohio', 1.5, 0],
#        [2001, 'Ohio', 1.7, 0],
#        [2002, 'Ohio', 3.6, 0],
#        [2001, 'Nevada', 2.4, 0],
#        [2002, 'Nevada', 2.9, 0]], dtype=object)

# %% [markdown]
# ## 索引对象

# %%
obj=Series(range(3),index=['a','b','c'])

# %%
index=obj.index

# %%
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
index=pd.Index(np.arange(3))

# %%
index
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
obj2=Series([1.5,-2.5,0],index=index)

# %%
obj2.index
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
obj2.index is index
# Out:
# True

# %%
frame3
# Out:
# state  Nevada  Ohio
# year
# 2000      NaN   1.5
# 2001      2.4   1.7
# 2002      2.9   3.6

# %%
'Ohio' in frame3.columns
# Out:
# True

# %%
2003 in frame3.index
# Out:
# False

# %% [markdown]
# ## 重新索引

# %%
obj=Series([4.5,7.2,-5.3,3.6],index=['d','b','a','c'])

# %%
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2=obj.reindex(['a','b','c','d','e'])

# %%
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj.reindex(['a','b','c','d','e'],fill_value=0)
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    0.0
# dtype: float64

# %%
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj3=Series(['blue','purple','yellow'],index=[0,2,4])

# %%
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
obj3.reindex(range(6),method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame=DataFrame(np.arange(9).reshape((3,3)),index=['a','c','d'],columns=['Ohio','Texas','California'])

# %%
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame2=frame.reindex(['a','b','c','d'])

# %%
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
states=['Texas','Utah','California']

# %%
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %%
frame.reindex(index=['a','b','c','d'],method='ffill',columns=states)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-ce4d39d82f08> in <module>()
# ----> 1 frame.reindex(index=['a','b','c','d'],method='ffill',columns=states)
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     185         @wraps(func)
#     186         def wrapper(*args, **kwargs):
# --> 187             return func(*args, **kwargs)
#     188
#     189         if not PY2:
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3564         kwargs.pop('axis', None)
#    3565         kwargs.pop('labels', None)
# -> 3566         return super(DataFrame, self).reindex(**kwargs)
#    3567
#    3568     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    3687         # perform the reindex on the axes
#    3688         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 3689                                   fill_value, copy).__finalize__(self)
#    3690
#    3691     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3494         if columns is not None:
#    3495             frame = frame._reindex_columns(columns, method, copy, level,
# -> 3496                                            fill_value, limit, tolerance)
#    3497
#    3498         index = axes['index']
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3516         new_columns, indexer = self.columns.reindex(new_columns, method=method,
#    3517                                                     level=level, limit=limit,
# -> 3518                                                     tolerance=tolerance)
#    3519         return self._reindex_with_indexers({1: [new_columns, indexer]},
#    3520                                            copy=copy, fill_value=fill_value,
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3620                     indexer = self.get_indexer(target, method=method,
#    3621                                                limit=limit,
# -> 3622                                                tolerance=tolerance)
#    3623                 else:
#    3624                     if method is not None or limit is not None:
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3246
#    3247         if method == 'pad' or method == 'backfill':
# -> 3248             indexer = self._get_fill_indexer(target, method, limit, tolerance)
#    3249         elif method == 'nearest':
#    3250             indexer = self._get_nearest_indexer(target, limit, tolerance)
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in _get_fill_indexer(self, target, method, limit, tolerance)
#    3276         else:
#    3277             indexer = self._get_fill_indexer_searchsorted(target, method,
# -> 3278                                                           limit)
#    3279         if tolerance is not None:
#    3280             indexer = self._filter_indexer_tolerance(target._ndarray_values,
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in _get_fill_indexer_searchsorted(self, target, method, limit)
#    3298         nonexact = (indexer == -1)
#    3299         indexer[nonexact] = self._searchsorted_monotonic(target[nonexact],
# -> 3300                                                          side)
#    3301         if side == 'left':
#    3302             # searchsorted returns "indices into a sorted array such that,
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in _searchsorted_monotonic(self, label, side)
#    4198             return len(self) - pos
#    4199
# -> 4200         raise ValueError('index must be monotonic increasing or decreasing')
#    4201
#    4202     def _get_loc_only_exact_matches(self, key):
#
# ValueError: index must be monotonic increasing or decreasing

# %% [markdown]
# ## 丢弃指定轴上的项

# %%
obj=Series(np.arange(5.),index=['a','b','c','d','e'])

# %%
new_obj=obj.drop('c')

# %%
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop(['d','c'])
# Out:
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
data=DataFrame(np.arange(16).reshape((4,4)),
              index=['Ohio','Colorado','Utah','New York'],
              columns=['one','two','three','four'])

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['Colorado','Ohio'])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop('two',axis=1)
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
data.drop(['two','four'],axis=1)
# Out:
#           one  three
# Ohio        0      2
# Colorado    4      6
# Utah        8     10
# New York   12     14

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# ## 索引 选取和过滤

# %%
obj=Series(np.arange(4.),index=['a','b','c','d'])

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj['b']
# Out:
# 1.0

# %%
obj[1]
# Out:
# 1.0

# %%
obj[2:4]
# Out:
# c    2.0
# d    3.0
# dtype: float64

# %%
obj[['b','a','d']]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
obj[[1,3]]
# Out:
# b    1.0
# d    3.0
# dtype: float64

# %%
obj[obj<2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
obj['b':'c']
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
obj['b':'c']=5

# %%
obj
# Out:
# a    0.0
# b    5.0
# c    5.0
# d    3.0
# dtype: float64

# %%
data=DataFrame(np.arange(16).reshape((4,4)),
              index=['Ohio','Colorado','Utah','New York'],
              columns=['one','two','three','four'])

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data['two']
# Out:
# Ohio         1
# Colorado     5
# Utah         9
# New York    13
# Name: two, dtype: int64

# %%
data[['three','one']]
# Out:
#           three  one
# Ohio          2    0
# Colorado      6    4
# Utah         10    8
# New York     14   12

# %%
data[:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %%
data[data['three']>5]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data<5
# Out:
#             one    two  three   four
# Ohio       True   True   True   True
# Colorado   True  False  False  False
# Utah      False  False  False  False
# New York  False  False  False  False

# %%
data[data<5]=0

# %%
data.ix['Colorado',['two','three']]
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# two      5
# three    6
# Name: Colorado, dtype: int64

# %%
data.ix[['Colorado','Utah'],[3,0,1]]
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#           four  one  two
# Colorado     7    0    5
# Utah        11    8    9

# %%
data.ix[2]
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# one       8
# two       9
# three    10
# four     11
# Name: Utah, dtype: int64

# %%
data.ix[:'Utah','two']
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Ohio        0
# Colorado    5
# Utah        9
# Name: two, dtype: int64

# %%
data.ix[data.three>5,:3]
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#           one  two  three
# Colorado    0    5      6
# Utah        8    9     10
# New York   12   13     14

# %% [markdown]
# ## 算数运算和数据对其

# %%
s1=Series([7.3,-2.5,3.4,1.5],index=['a','c','d','e'])

# %%
frame=DataFrame(np.arange(12.).reshape((4,3))

# %% [markdown]
# ## Reshaping Data

# %%
data2={'Date':['2016-03-01',
              '2016-03-02',
              '2016-03-01',
              '2016-03-03',
              '2016-03-02',
              '2016-03-03'],
      'Type':['a',
             'b',
             'c',
             'a',
             'a',
             'c'],
      'Value':[11.432,
              13.031,
              20.784,
              99.906,
              1.303,
              20.784]}
df2=pd.DataFrame(data2,columns=['Date','Type','Value'])
df2
# Out:
#          Date Type   Value
# 0  2016-03-01    a  11.432
# 1  2016-03-02    b  13.031
# 2  2016-03-01    c  20.784
# 3  2016-03-03    a  99.906
# 4  2016-03-02    a   1.303
# 5  2016-03-03    c  20.784

# %%
df3=df2.pivot(columns='Type',values='Value')
df3
# Out:
# Type       a       b       c
# 0     11.432     NaN     NaN
# 1        NaN  13.031     NaN
# 2        NaN     NaN  20.784
# 3     99.906     NaN     NaN
# 4      1.303     NaN     NaN
# 5        NaN     NaN  20.784

# %%
df4=pd.pivot_table(df2,values='Value',index='Date',columns='Type')
df4
# Out:
# Type             a       b       c
# Date
# 2016-03-01  11.432     NaN  20.784
# 2016-03-02   1.303  13.031     NaN
# 2016-03-03  99.906     NaN  20.784

# %%
pd.melt(df2,id_vars=['Date'],value_vars=['Type','Value'],value_name='Observations')
# Out:
#           Date variable Observations
# 0   2016-03-01     Type            a
# 1   2016-03-02     Type            b
# 2   2016-03-01     Type            c
# 3   2016-03-03     Type            a
# 4   2016-03-02     Type            a
# 5   2016-03-03     Type            c
# 6   2016-03-01    Value       11.432
# 7   2016-03-02    Value       13.031
# 8   2016-03-01    Value       20.784
# 9   2016-03-03    Value       99.906
# 10  2016-03-02    Value        1.303
# 11  2016-03-03    Value       20.784

# %%
data={'Country':['Belgium','India','Brazil'],
     'Capital':['Brussels','New Delhi','Brasilia'],
     'Population':[11190846,1303171035,207847528]}
df=pd.DataFrame(data,columns=['Country','Capital','Population'])
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
df.iteritems()
# Out:
# <generator object DataFrame.iteritems at 0x11127d6d0>

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x11127d888>

# %%
df3.loc[:,(df3>1).any()]
# Out:
# Type             a       b       c
# Date
# 2016-03-01  11.432     NaN  20.784
# 2016-03-02   1.303  13.031     NaN
# 2016-03-03  99.906     NaN  20.784

# %%
df3.loc[:,(df3>1).all()]
# Out:
# Type             a
# Date
# 2016-03-01  11.432
# 2016-03-02   1.303
# 2016-03-03  99.906

# %%
df3.loc[:,df3.isnull().any()]
# Out:
# Type             b       c
# Date
# 2016-03-01     NaN  20.784
# 2016-03-02  13.031     NaN
# 2016-03-03     NaN  20.784

# %%
df3.loc[:,df3.notnull().all()]
# Out:
# Type             a
# Date
# 2016-03-01  11.432
# 2016-03-02   1.303
# 2016-03-03  99.906

# %%
df[(df.Country.isin(df2.Type))]
# Out:
# Empty DataFrame
# Columns: [Country, Capital, Population]
# Index: []

# %%
df3.filter(items=['a','b'])
# Out:
# Type             a       b
# Date
# 2016-03-01  11.432     NaN
# 2016-03-02   1.303  13.031
# 2016-03-03  99.906     NaN

# %%
df.select(lambda x:not x%5)
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'select' is deprecated and will be removed in a future release. You can use .loc[labels.map(crit)] as a replacement
#   if __name__ == '__main__':
#    Country   Capital  Population
# 0  Belgium  Brussels    11190846

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
s.where(s>0)
# Out:
# a    3.0
# b    NaN
# c    7.0
# d    4.0
# dtype: float64

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
df4
# Out:
# Type             a       b       c
# Date
# 2016-03-01  11.432     NaN  20.784
# 2016-03-02   1.303  13.031     NaN
# 2016-03-03  99.906     NaN  20.784

# %%
df.set_index('Country')
# Out:
#            Capital  Population
# Country
# Belgium   Brussels    11190846
# India    New Delhi  1303171035
# Brazil    Brasilia   207847528

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
df4=df.reset_index()
df4
# Out:
#    index  Country    Capital  Population
# 0      0  Belgium   Brussels    11190846
# 1      1    India  New Delhi  1303171035
# 2      2   Brazil   Brasilia   207847528

# %%
df=df.rename(index=str,columns={'Country':'cntry',
                               'Capital':'cptl',
                               'Population':'ppltn'})
df
# Out:
#      cntry       cptl       ppltn
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
s2=s.reindex(['a','c','d','e','b'])
s2
# Out:
# a    3.0
# c    7.0
# d    4.0
# e    NaN
# b   -5.0
# dtype: float64

# %%
df
# Out:
#      cntry       cptl       ppltn
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
s3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-99e5fac9ea42> in <module>()
# ----> 1 s3
#
# NameError: name 's3' is not defined

# %%
df2
# Out:
#          Date Type   Value
# 0  2016-03-01    a  11.432
# 1  2016-03-02    b  13.031
# 2  2016-03-01    c  20.784
# 3  2016-03-03    a  99.906
# 4  2016-03-02    a   1.303
# 5  2016-03-03    c  20.784

# %%
df2.groupby(by=['Date','Type']).mean()
# Out:
#                   Value
# Date       Type
# 2016-03-01 a     11.432
#            c     20.784
# 2016-03-02 a      1.303
#            b     13.031
# 2016-03-03 a     99.906
#            c     20.784

# %% [markdown]
# ## GroupBy

# %%
df=DataFrame({
    'key1':['a','a','b','b','a'],
    'key2':['one','two','one','two','one'],
    'data1':np.random.randn(5),
    'data2':np.random.randn(5)
})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.403413  0.551936
# 1    a  two  0.390351  0.833303
# 2    b  one  0.774573 -1.572771
# 3    b  two -1.855184  0.880644
# 4    a  one -1.924288  0.648058

# %%
grouped=df['data1'].groupby(df['key1'])

# %%
grouped

# %%
grouped.mean()
# Out:
# key1
# a   -0.376842
# b   -0.540305
# Name: data1, dtype: float64

# %%
means=df['data1'].groupby([df['key1'],df['key2']]).mean()

# %%
means
# Out:
# key1  key2
# a     one    -0.760438
#       two     0.390351
# b     one     0.774573
#       two    -1.855184
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a    -0.760438  0.390351
# b     0.774573 -1.855184

# %%
states=np.array(['Ohio','California','California','Ohio','Ohio'])

# %%
years=np.array([2005,2005,2006,2005,2006])

# %%
df['data1']
# Out:
# 0    0.403413
# 1    0.390351
# 2    0.774573
# 3   -1.855184
# 4   -1.924288
# Name: data1, dtype: float64

# %%
df['data1'].groupby([states,years]).mean()
# Out:
# California  2005    0.390351
#             2006    0.774573
# Ohio        2005   -0.725886
#             2006   -1.924288
# Name: data1, dtype: float64

# %%
df.groupby('key1').mean()
# Out:
#          data1     data2
# key1
# a    -0.376842  0.677766
# b    -0.540305 -0.346064

# %%
df.groupby(['key1','key2']).mean()
# Out:
#               data1     data2
# key1 key2
# a    one  -0.760438  0.599997
#      two   0.390351  0.833303
# b    one   0.774573 -1.572771
#      two  -1.855184  0.880644

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.403413  0.551936
# 1    a  two  0.390351  0.833303
# 2    b  one  0.774573 -1.572771
# 3    b  two -1.855184  0.880644
# 4    a  one -1.924288  0.648058

# %%
df.groupby(['key1','key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %%
for name,group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one  0.403413  0.551936
# 1    a  two  0.390351  0.833303
# 4    a  one -1.924288  0.648058
# b
#   key1 key2     data1     data2
# 2    b  one  0.774573 -1.572771
# 3    b  two -1.855184  0.880644

# %%
for (k1, k2), group in df.groupby(['key1','key2']):
    print(k1, k2)
    print(group)
# Out:
# a one
#   key1 key2     data1     data2
# 0    a  one  0.403413  0.551936
# 4    a  one -1.924288  0.648058
# a two
#   key1 key2     data1     data2
# 1    a  two  0.390351  0.833303
# b one
#   key1 key2     data1     data2
# 2    b  one  0.774573 -1.572771
# b two
#   key1 key2     data1     data2
# 3    b  two -1.855184  0.880644

# %%
pieces=dict(list(df.groupby('key1')))

# %%
pieces['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one  0.774573 -1.572771
# 3    b  two -1.855184  0.880644

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.403413  0.551936
# 1    a  two  0.390351  0.833303
# 2    b  one  0.774573 -1.572771
# 3    b  two -1.855184  0.880644
# 4    a  one -1.924288  0.648058

# %%
df.dtypes
# Out:
# key1      object
# key2      object
# data1    float64
# data2    float64
# dtype: object

# %%
grouped=df.groupby(df.dtypes,axis=1)

# %%
dict(list(grouped))
# Out:
# {dtype('float64'):       data1     data2
#  0  0.403413  0.551936
#  1  0.390351  0.833303
#  2  0.774573 -1.572771
#  3 -1.855184  0.880644
#  4 -1.924288  0.648058, dtype('O'):   key1 key2
#  0    a  one
#  1    a  two
#  2    b  one
#  3    b  two
#  4    a  one}

# %%
df.groupby('key1')['data1']

# %%
df.groupby('key1')[['data2']]

# %%
df['data1'].groupby(df['key1'])

# %%
df[['data2']].groupby(df['key1'])

# %%
df.groupby(['key1','key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    one   0.599997
#      two   0.833303
# b    one  -1.572771
#      two   0.880644

# %%
s_grouped=df.groupby(['key1','key2'])['data2']

# %%
s_grouped

# %%
s_grouped.mean()
# Out:
# key1  key2
# a     one     0.599997
#       two     0.833303
# b     one    -1.572771
#       two     0.880644
# Name: data2, dtype: float64

# %%
people=DataFrame(np.random.randn(5,5),
                columns=['a','b','c','d','e'],
                index=['Joe','Steve','Wes','Jim','Travis'])

# %%
people.ix[2:3,['b','c']]=np.nan
# Out:
# /Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
people
# Out:
#                a         b         c         d         e
# Joe     0.830327 -0.764052  0.668612  1.632914  1.220237
# Steve   1.297102  2.719766  0.172358  1.545216 -0.547841
# Wes    -0.563548       NaN       NaN -2.222069  0.867952
# Jim    -1.172775 -0.003064 -1.873642  0.157703  0.573098
# Travis -0.725304 -0.544912 -0.797475 -1.009178 -0.322351

# %%
mapping={
    'a':'red',
    'b':'red',
    'c':'blue',
    'd':'blue',
    'e':'red',
    'f':'orange'
}

# %%
by_column=people.groupby(mapping,axis=1)

# %%
by_column.sum()
# Out:
#             blue       red
# Joe     2.301526  1.286512
# Steve   1.717574  3.469027
# Wes    -2.222069  0.304403
# Jim    -1.715939 -0.602741
# Travis -1.806653 -1.592567

# %%
map_series=Series(mapping)

# %%
map_series
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object

# %%
people.groupby(map_series,axis=1).count()
# Out:
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %%
people
# Out:
#                a         b         c         d         e
# Joe     0.830327 -0.764052  0.668612  1.632914  1.220237
# Steve   1.297102  2.719766  0.172358  1.545216 -0.547841
# Wes    -0.563548       NaN       NaN -2.222069  0.867952
# Jim    -1.172775 -0.003064 -1.873642  0.157703  0.573098
# Travis -0.725304 -0.544912 -0.797475 -1.009178 -0.322351

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3 -0.905996 -0.767116 -1.205030 -0.431452  2.661287
# 5  1.297102  2.719766  0.172358  1.545216 -0.547841
# 6 -0.725304 -0.544912 -0.797475 -1.009178 -0.322351

# %%
key_list=['one','one','one','two','two']

# %%
people.groupby([len,key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one -0.563548 -0.764052  0.668612 -2.222069  0.867952
#   two -1.172775 -0.003064 -1.873642  0.157703  0.573098
# 5 one  1.297102  2.719766  0.172358  1.545216 -0.547841
# 6 two -0.725304 -0.544912 -0.797475 -1.009178 -0.322351

# %%
columns=pd.MultiIndex.from_arrays([['US','US','US','JP','JP'],
                                   [1,3,5,1,3]],
                                  names=['city','tenor'])

# %%
hier_df=DataFrame(np.random.randn(4,5),columns=columns)

# %%
hier_df
# Out:
# city         US                            JP
# tenor         1         3         5         1         3
# 0     -0.208366  0.622540  1.140302 -0.109216  0.158793
# 1     -0.831522 -0.416285 -0.095183 -0.210106  2.125300
# 2      0.274338 -0.394544 -0.487525  0.486827  2.078913
# 3      1.202761 -0.401440  1.637654 -0.292284  0.321868

# %%
hier_df.groupby(level='city',axis=1).count()
# Out:
# city  JP  US
# 0      2   3
# 1      2   3
# 2      2   3
# 3      2   3

# %% [markdown]
# ## 数据聚合

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.403413  0.551936
# 1    a  two  0.390351  0.833303
# 2    b  one  0.774573 -1.572771
# 3    b  two -1.855184  0.880644
# 4    a  one -1.924288  0.648058

# %%
grouped=df.groupby('key1')

# %%
grouped['data1'].quantile(0.9)
# Out:
# key1
# a    0.400800
# b    0.511598
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
    return arr.max()-arr.min()

# %%
grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     2.327701  0.281366
# b     2.629757  2.453415

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0 -0.376842  1.340144 -1.924288 -0.766969  0.390351  0.396882
# b      2.0 -0.540305  1.859519 -1.855184 -1.197745 -0.540305  0.117134
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a     0.403413   3.0  0.677766  0.143016  0.551936  0.599997  0.648058
# b     0.774573   2.0 -0.346064  1.734827 -1.572771 -0.959418 -0.346064
#
#
#            75%       max
# key1
# a     0.740681  0.833303
# b     0.267290  0.880644

# %%
tips=pd.read_csv('/Users/liuxiaochi/Documents/PythonCode/Python_for_Data_Analysis/ch08/tips.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['tip_pct']=tips['tip']/tips['total_bill']

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# 5         25.29  4.71    Male     No   Sun  Dinner     4  0.186240
# 6          8.77  2.00    Male     No   Sun  Dinner     2  0.228050
# 7         26.88  3.12    Male     No   Sun  Dinner     4  0.116071
# 8         15.04  1.96    Male     No   Sun  Dinner     2  0.130319
# 9         14.78  3.23    Male     No   Sun  Dinner     2  0.218539
# 10        10.27  1.71    Male     No   Sun  Dinner     2  0.166504
# 11        35.26  5.00  Female     No   Sun  Dinner     4  0.141804
# 12        15.42  1.57    Male     No   Sun  Dinner     2  0.101816
# 13        18.43  3.00    Male     No   Sun  Dinner     4  0.162778
# 14        14.83  3.02  Female     No   Sun  Dinner     2  0.203641
# 15        21.58  3.92    Male     No   Sun  Dinner     2  0.181650
# 16        10.33  1.67  Female     No   Sun  Dinner     3  0.161665
# 17        16.29  3.71    Male     No   Sun  Dinner     3  0.227747
# 18        16.97  3.50  Female     No   Sun  Dinner     3  0.206246
# 19        20.65  3.35    Male     No   Sat  Dinner     3  0.162228
# 20        17.92  4.08    Male     No   Sat  Dinner     2  0.227679
# 21        20.29  2.75  Female     No   Sat  Dinner     2  0.135535
# 22        15.77  2.23  Female     No   Sat  Dinner     2  0.141408
# 23        39.42  7.58    Male     No   Sat  Dinner     4  0.192288
# 24        19.82  3.18    Male     No   Sat  Dinner     2  0.160444
# 25        17.81  2.34    Male     No   Sat  Dinner     4  0.131387
# 26        13.37  2.00    Male     No   Sat  Dinner     2  0.149589
# 27        12.69  2.00    Male     No   Sat  Dinner     2  0.157604
# 28        21.70  4.30    Male     No   Sat  Dinner     2  0.198157
# 29        19.65  3.00  Female     No   Sat  Dinner     2  0.152672
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3  0.230742
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2  0.085271
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5  0.106572
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2  0.129422
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2  0.186047
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4  0.102522
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2  0.180921
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  0.259314
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1  0.223776
# 223       15.98  3.00  Female     No   Fri   Lunch     3  0.187735
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2  0.117735
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2  0.153657
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2  0.198216
# 227       20.45  3.00    Male     No   Sat  Dinner     4  0.146699
# 228       13.28  2.72    Male     No   Sat  Dinner     2  0.204819
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2  0.130199
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4  0.083299
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3  0.191205
# 232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# 233       10.77  1.47    Male     No   Sat  Dinner     2  0.136490
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  0.193175
# 235       10.07  1.25    Male     No   Sat  Dinner     2  0.124131
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  0.079365
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2  0.035638
# 238       35.83  4.67  Female     No   Sat  Dinner     3  0.130338
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %%
grouped=tips.groupby(['sex','smoker'])
grouped

# %%
grouped_pct=grouped['tip_pct']
grouped_pct

# %%
grouped_pct.agg('mean')
# Out:
# sex     smoker
# Female  No        0.156921
#         Yes       0.182150
# Male    No        0.160669
#         Yes       0.152771
# Name: tip_pct, dtype: float64

# %%
grouped_pct.agg(['mean','std',peak_to_peak])
# Out:
#                    mean       std  peak_to_peak
# sex    smoker
# Female No      0.156921  0.036421      0.195876
#        Yes     0.182150  0.071595      0.360233
# Male   No      0.160669  0.041849      0.220186
#        Yes     0.152771  0.090588      0.674707

# %%
grouped_pct.agg([('foo','mean'),('bar',np.std)])
# Out:
#                     foo       bar
# sex    smoker
# Female No      0.156921  0.036421
#        Yes     0.182150  0.071595
# Male   No      0.160669  0.041849
#        Yes     0.152771  0.090588

# %%
functions=['count','mean','max']

# %%
result=grouped['tip_pct','total_bill'].agg(functions)

# %%
result
# Out:
#               tip_pct                     total_bill
#                 count      mean       max      count       mean    max
# sex    smoker
# Female No          54  0.156921  0.252672         54  18.105185  35.83
#        Yes         33  0.182150  0.416667         33  17.977879  44.30
# Male   No          97  0.160669  0.291990         97  19.791237  48.33
#        Yes         60  0.152771  0.710345         60  22.284500  50.81

# %%
result['tip_pct']
# Out:
#                count      mean       max
# sex    smoker
# Female No         54  0.156921  0.252672
#        Yes        33  0.182150  0.416667
# Male   No         97  0.160669  0.291990
#        Yes        60  0.152771  0.710345

# %%
ftuples=[('Durchschnitt','mean'),('Abweichung',np.var)]

# %%
grouped['tip_pct','total_bill'].agg(ftuples)
# Out:
#                    tip_pct              total_bill
#               Durchschnitt Abweichung Durchschnitt Abweichung
# sex    smoker
# Female No         0.156921   0.001327    18.105185  53.092422
#        Yes        0.182150   0.005126    17.977879  84.451517
# Male   No         0.160669   0.001751    19.791237  76.152961
#        Yes        0.152771   0.008206    22.284500  98.244673

# %%
grouped

# %%
grouped.agg({'tip':np.max,'size':'sum'})
# Out:
#                 tip  size
# sex    smoker
# Female No       5.2   140
#        Yes      6.5    74
# Male   No       9.0   263
#        Yes     10.0   150

# %%
grouped.agg({'tip_pct':['min','max','mean','std'],'size':'sum'})
# Out:
#                 tip_pct                               size
#                     min       max      mean       std  sum
# sex    smoker
# Female No      0.056797  0.252672  0.156921  0.036421  140
#        Yes     0.056433  0.416667  0.182150  0.071595   74
# Male   No      0.071804  0.291990  0.160669  0.041849  263
#        Yes     0.035638  0.710345  0.152771  0.090588  150

# %% [markdown]
# ## 分组级运算和转换

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.403413  0.551936
# 1    a  two  0.390351  0.833303
# 2    b  one  0.774573 -1.572771
# 3    b  two -1.855184  0.880644
# 4    a  one -1.924288  0.648058

# %%
k1_means=df.groupby('key1').mean().add_prefix('mean')

# %%
k1_means
# Out:
#       meandata1  meandata2
# key1
# a     -0.376842   0.677766
# b     -0.540305  -0.346064

# %%
pd.merge(df,k1_means,left_on='key1',right_index=True)
# Out:
#   key1 key2     data1     data2  meandata1  meandata2
# 0    a  one  0.403413  0.551936  -0.376842   0.677766
# 1    a  two  0.390351  0.833303  -0.376842   0.677766
# 4    a  one -1.924288  0.648058  -0.376842   0.677766
# 2    b  one  0.774573 -1.572771  -0.540305  -0.346064
# 3    b  two -1.855184  0.880644  -0.540305  -0.346064

# %%
people
# Out:
#                a         b         c         d         e
# Joe     0.830327 -0.764052  0.668612  1.632914  1.220237
# Steve   1.297102  2.719766  0.172358  1.545216 -0.547841
# Wes    -0.563548       NaN       NaN -2.222069  0.867952
# Jim    -1.172775 -0.003064 -1.873642  0.157703  0.573098
# Travis -0.725304 -0.544912 -0.797475 -1.009178 -0.322351

# %%
key=['one','two','one','two','one']

# %%
people.groupby(key).mean()
# Out:
#             a         b         c         d         e
# one -0.152842 -0.654482 -0.064432 -0.532777  0.588612
# two  0.062163  1.358351 -0.850642  0.851459  0.012629

# %%
people.groupby(key).transform(np.mean)
# Out:
#                a         b         c         d         e
# Joe    -0.152842 -0.654482 -0.064432 -0.532777  0.588612
# Steve   0.062163  1.358351 -0.850642  0.851459  0.012629
# Wes    -0.152842 -0.654482 -0.064432 -0.532777  0.588612
# Jim     0.062163  1.358351 -0.850642  0.851459  0.012629
# Travis -0.152842 -0.654482 -0.064432 -0.532777  0.588612

# %%
def demean(arr):
    return arr - arr.mean()

# %%
demeaned=people.groupby(key).transform(demean)

# %%
demeaned
# Out:
#                a         b         c         d         e
# Joe     0.983169 -0.109570  0.733043  2.165692  0.631625
# Steve   1.234939  1.361415  1.023000  0.693756 -0.560470
# Wes    -0.410707       NaN       NaN -1.689292  0.279339
# Jim    -1.234939 -1.361415 -1.023000 -0.693756  0.560470
# Travis -0.572463  0.109570 -0.733043 -0.476400 -0.910964

# %%
demeaned.groupby(key).mean()
# Out:
#        a    b             c             d    e
# one  0.0  0.0  0.000000e+00  7.401487e-17  0.0
# two  0.0  0.0 -1.110223e-16  0.000000e+00  0.0

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.403413  0.551936
# 1    a  two  0.390351  0.833303
# 2    b  one  0.774573 -1.572771
# 3    b  two -1.855184  0.880644
# 4    a  one -1.924288  0.648058

# %%
ax=df.boxplot(column=['data1'],by='key1')

myDF.groupby(['deltaMonth'])['BLL'].mean().plot(
    label='mean of BLL',
    yticks=np.linspace(0,90,10,dtype=int),
    style='o-',
    legend=True,
    sharex=True,
    grid=True
)

# %%
ax=df.boxplot(column=['data1'],by='key1')
df.groupby(['key1'])['data1'].mean().plot(
    style='o-',
    grid=True,
    ax=ax
)

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Anatomy

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x=[1,2,3,4]

# %%
y=[10,20,25,30]

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
ax=fig.add_subplot(111)

# %%
ax.plot(x,y,color='lightblue',linewidth=3)

# %%
ax.scatter([2,4,6],
          [5,15,25],
          color='darkgreen',
          marker='^')

# %%
ax.set_xlim(1,6.5)
# Out:
# (1, 6.5)

# %%
plt.savefig('foo.png')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
plt.show()

# %% [markdown]
# ## Prepare The Data

# %%
import numpy as np
import matplotlib

# %%
x=np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y=np.cos(x)
y
# Out:
# array([ 1.        ,  0.99490282,  0.97966323,  0.95443659,  0.91948007,
#         0.87515004,  0.8218984 ,  0.76026803,  0.69088721,  0.61446323,
#         0.53177518,  0.44366602,  0.35103397,  0.25482335,  0.15601496,
#         0.0556161 , -0.04534973, -0.14585325, -0.24486989, -0.34139023,
#        -0.43443032, -0.52304166, -0.60632092, -0.68341913, -0.75355031,
#        -0.81599952, -0.87013012, -0.91539031, -0.95131866, -0.97754893,
#        -0.9938137 , -0.99994717, -0.9958868 , -0.981674  , -0.95745366,
#        -0.92347268, -0.88007748, -0.82771044, -0.76690542, -0.69828229,
#        -0.6225406 , -0.54045251, -0.45285485, -0.36064061, -0.26474988,
#        -0.16616018, -0.06587659,  0.03507857,  0.13567613,  0.23489055,
#         0.33171042,  0.4251487 ,  0.51425287,  0.59811455,  0.67587883,
#         0.74675295,  0.8100144 ,  0.86501827,  0.91120382,  0.94810022,
#         0.97533134,  0.99261957,  0.99978867,  0.99676556,  0.98358105,
#         0.96036956,  0.9273677 ,  0.88491192,  0.83343502,  0.77346177,
#         0.70560358,  0.63055219,  0.54907273,  0.46199582,  0.37020915,
#         0.27464844,  0.17628785,  0.07613012, -0.0248037 , -0.12548467,
#        -0.2248864 , -0.32199555, -0.41582217, -0.50540974, -0.58984498,
#        -0.66826712, -0.7398767 , -0.8039437 , -0.859815  , -0.90692104,
#        -0.94478159, -0.97301068, -0.99132055, -0.99952453, -0.99753899,
#        -0.98538417, -0.96318398, -0.93116473, -0.88965286, -0.83907153])

# %%
z=np.sin(x)
z
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
#         0.27872982,  0.37415123,  0.46575841,  0.55261747,  0.63384295,
#         0.7086068 ,  0.77614685,  0.83577457,  0.8868821 ,  0.92894843,
#         0.96154471,  0.98433866,  0.99709789,  0.99969234,  0.99209556,
#         0.97438499,  0.94674118,  0.90944594,  0.86287948,  0.8075165 ,
#         0.74392141,  0.6727425 ,  0.59470541,  0.51060568,  0.42130064,
#         0.32770071,  0.23076008,  0.13146699,  0.03083368, -0.07011396,
#        -0.17034683, -0.26884313, -0.36459873, -0.45663749, -0.54402111])

# %%
data=2*np.random.random((10,10))
data
# Out:
# array([[0.48630956, 0.10132132, 0.76255065, 1.68843498, 1.95506925,
#         0.58016855, 1.1149494 , 0.46880558, 0.84858865, 1.71353099],
#        [1.94619124, 0.45214949, 1.37364361, 1.9186713 , 1.25583166,
#         0.51861394, 0.76620017, 1.46797986, 0.19041258, 1.62464952],
#        [0.24973178, 1.34090437, 1.03756251, 1.437665  , 1.66260482,
#         0.26132844, 0.14239801, 1.87397546, 1.83759788, 0.0825253 ],
#        [1.31840012, 1.79839729, 1.38415921, 0.85738801, 1.30598048,
#         1.62895418, 1.25224213, 0.72584132, 1.56134316, 1.82505381],
#        [1.81089365, 0.09043334, 0.55788721, 1.85108841, 0.66954347,
#         1.09329716, 1.38366157, 1.09789126, 0.52129677, 0.96616446],
#        [1.17925381, 0.0290449 , 0.51469226, 1.47856181, 0.44581803,
#         1.89860819, 0.97782144, 1.03277776, 1.82608345, 0.63721522],
#        [0.83459466, 0.95248667, 0.40723263, 1.75425389, 0.52009256,
#         0.97692127, 1.25033974, 0.60035399, 0.31389965, 1.01592029],
#        [0.4085072 , 0.95154997, 0.94694495, 0.97135532, 0.95132395,
#         1.30082052, 1.51655983, 0.6069904 , 0.51408486, 0.54386497],
#        [1.80856215, 0.7755319 , 0.80872723, 0.32316586, 0.19309255,
#         0.36651245, 0.27562658, 0.25058524, 1.89015041, 0.58173882],
#        [1.4029585 , 0.89292506, 0.16403579, 0.90064345, 1.53291349,
#         0.70741658, 1.24611844, 0.16876294, 1.94978537, 0.66565624]])

# %%
data2=3*np.random.random((10,10))
data2
# Out:
# array([[0.14950104, 2.18113659, 2.29520018, 1.94679265, 2.44886875,
#         2.27603388, 2.41439057, 0.81967829, 0.94772034, 2.6630764 ],
#        [2.00842794, 1.50814943, 0.18403524, 2.70485466, 2.73437452,
#         2.58484456, 2.36106956, 2.77000945, 1.76186222, 0.12812725],
#        [0.80514603, 0.34367519, 0.99562352, 2.12051833, 0.75534184,
#         2.34948871, 2.76360992, 1.52354382, 2.74192834, 2.42894977],
#        [2.12502162, 1.75327212, 2.8103847 , 0.83950523, 1.42050193,
#         0.4201219 , 2.81705668, 1.58518816, 2.88296905, 0.13889614],
#        [0.32949978, 0.27836573, 1.93503284, 2.01045694, 0.82887436,
#         0.00502502, 0.9236359 , 0.75033274, 2.39947536, 0.45317837],
#        [0.8753201 , 2.35762634, 0.29619793, 1.48220649, 2.38502742,
#         0.77131689, 0.76341439, 1.41740925, 2.07561378, 0.70653154],
#        [2.03282417, 2.39340144, 0.14762699, 0.75665393, 1.62301242,
#         1.68837776, 2.30619774, 1.96763307, 1.90186971, 2.39116342],
#        [1.74012743, 2.11948668, 2.61825481, 2.34893107, 2.87487889,
#         1.7256672 , 0.77922472, 2.14769501, 0.52539055, 0.27182656],
#        [1.96469121, 2.05627243, 1.52664691, 0.83389841, 1.24300416,
#         2.6667344 , 0.29080568, 2.22752893, 2.28464141, 0.16237321],
#        [0.77800801, 2.15957168, 2.38091277, 2.42785319, 0.22126781,
#         1.85030575, 0.62077888, 1.21324548, 1.62612397, 2.08702315]])

# %%
Y,X=np.mgrid[-3:3:100j,-3:3:100j]

# %%
Y
# Out:
# array([[-3.        , -3.        , -3.        , ..., -3.        ,
#         -3.        , -3.        ],
#        [-2.93939394, -2.93939394, -2.93939394, ..., -2.93939394,
#         -2.93939394, -2.93939394],
#        [-2.87878788, -2.87878788, -2.87878788, ..., -2.87878788,
#         -2.87878788, -2.87878788],
#        ...,
#        [ 2.87878788,  2.87878788,  2.87878788, ...,  2.87878788,
#          2.87878788,  2.87878788],
#        [ 2.93939394,  2.93939394,  2.93939394, ...,  2.93939394,
#          2.93939394,  2.93939394],
#        [ 3.        ,  3.        ,  3.        , ...,  3.        ,
#          3.        ,  3.        ]])

# %%
X
# Out:
# array([[-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        ...,
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ]])

# %%
U=-1-X**2+Y
U
# Out:
# array([[-13.        , -12.64003673, -12.28741965, ..., -12.28741965,
#         -12.64003673, -13.        ],
#        [-12.93939394, -12.57943067, -12.22681359, ..., -12.22681359,
#         -12.57943067, -12.93939394],
#        [-12.87878788, -12.51882461, -12.16620753, ..., -12.16620753,
#         -12.51882461, -12.87878788],
#        ...,
#        [ -7.12121212,  -6.76124885,  -6.40863177, ...,  -6.40863177,
#          -6.76124885,  -7.12121212],
#        [ -7.06060606,  -6.70064279,  -6.34802571, ...,  -6.34802571,
#          -6.70064279,  -7.06060606],
#        [ -7.        ,  -6.64003673,  -6.28741965, ...,  -6.28741965,
#          -6.64003673,  -7.        ]])

# %%
V=1+X-Y**2
V
# Out:
# array([[-11.        , -10.93939394, -10.87878788, ...,  -5.12121212,
#          -5.06060606,  -5.        ],
#        [-10.64003673, -10.57943067, -10.51882461, ...,  -4.76124885,
#          -4.70064279,  -4.64003673],
#        [-10.28741965, -10.22681359, -10.16620753, ...,  -4.40863177,
#          -4.34802571,  -4.28741965],
#        ...,
#        [-10.28741965, -10.22681359, -10.16620753, ...,  -4.40863177,
#          -4.34802571,  -4.28741965],
#        [-10.64003673, -10.57943067, -10.51882461, ...,  -4.76124885,
#          -4.70064279,  -4.64003673],
#        [-11.        , -10.93939394, -10.87878788, ...,  -5.12121212,
#          -5.06060606,  -5.        ]])

# %%
from matplotlib.cbook import get_sample_data

# %%
import matplotlib as mpl

# %%
import matplotlib.cbook as cbook

# %%
img=np.load(get_sample_data('axes_grid/bivariate_noraml.npy'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-d4fb3341f1f2> in <module>()
# ----> 1 img=np.load(get_sample_data('axes_grid/bivariate_noraml.npy'))
#
# ~/anaconda3/envs/py3.6/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in get_sample_data(fname, asfileobj)
#     680             return gzip.open(path, mode)
#     681         else:
# --> 682             return open(path, mode)
#     683     else:
#     684         return path
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/liuxiaochi/anaconda3/envs/py3.6/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/axes_grid/bivariate_noraml.npy'

# %% [markdown]
# ## Figure Subplot

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ax1=fig.add_subplot(2,2,1)

# %%
ax2=fig.add_subplot(2,2,2)

# %%
ax3=fig.add_subplot(2,2,3)

# %%
from numpy.random import randn

# %%
plt.plot(randn(50).cumsum(),'k--')

# %%
ax1.hist(randn(100),bins=20,color='k',alpha=0.3)
# Out:
# (array([ 3.,  1.,  3.,  1.,  5., 12.,  8., 13., 12.,  7.,  8.,  9.,  2.,
#          5.,  2.,  2.,  3.,  1.,  2.,  1.]),
#  array([-2.23254581, -1.98050233, -1.72845885, -1.47641537, -1.22437188,
#         -0.9723284 , -0.72028492, -0.46824144, -0.21619796,  0.03584552,
#          0.287889  ,  0.53993248,  0.79197596,  1.04401944,  1.29606292,
#          1.5481064 ,  1.80014988,  2.05219336,  2.30423684,  2.55628032,
#          2.8083238 ]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30),np.arange(30)+3*randn(30))

# %%
fig,axes=plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112629b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11268d5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11299dc50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1129c7b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x102edd208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1061b5860>]],
#       dtype=object)

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
for i in range(2):
    for j in range(2):
        axes[i,j].hist(randn(500),bins=50,color='k',alpha=0.5)

# %%
plt.subplots_adjust(wspace=0,hspace=0)

# %% [markdown]
# ## 颜色、标记和线型

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
data=randn(30).cumsum()
data
# Out:
# array([ 1.42969117,  1.59785826,  3.63921455,  4.00927736,  4.87372081,
#         3.27404897,  5.24849122,  6.44061312,  4.40408814,  3.64960799,
#         3.50851283,  2.44708069,  2.08883027,  1.87451488,  3.29371422,
#         1.8628363 ,  3.0887029 ,  2.84994488,  1.29561397,  0.47308075,
#         2.69163175,  2.12541936,  2.87786802,  2.91207574,  2.02279764,
#         1.99094578,  2.47049486,  1.79897194, -0.50368928, -0.70090988])

# %%
ax=plt.plot(data,'k--',label='Default')

# %%
plt.plot(data,'k-',drawstyle='steps-post',label='steps-post')

# %%
plt.legend(loc='best')

# %% [markdown]
# ## 刻度、标签和图例

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ax=fig.add_subplot(1,1,1)

# %%
ax.plot(randn(1000).cumsum())

# %%
ticks=ax.set_xticks([0,250,500,750,1000])

# %%
labels=ax.set_xticklabels(['one','two','three','four','five'],rotation=30,fontsize='small')

# %%
ax.set_title('My first matplotlib plot')
# Out:
# Text(0.5,1,'My first matplotlib plot')

# %%
ax.set_xlabel('Stages')
# Out:
# Text(0.5,14.8221,'Stages')

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ax=fig.add_subplot(1,1,1)

# %%
ax.plot(randn(1000).cumsum(),'k',label='one')

# %%
ax.plot(randn(1000).cumsum(),'k--',label='two')

# %%
ax.plot(randn(1000).cumsum(),'k.',label='three')

# %%
ax.legend(loc='best')

# %% [markdown]
# ## 保存图片

# %%
plt.savefig('/Users/liuxiaochi/Desktop/fig.png',dpi=400,bbox_inches='tight')

# %% [markdown]
# ## 线形图

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
s=pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))

# %%
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),
            columns=['A','B','C','D'],
            index=np.arange(0,100,10))
df
# Out:
#            A         B         C         D
# 0  -1.772363  0.147009  0.873856  0.065138
# 10 -3.383430  0.311895  0.663538 -0.156148
# 20 -2.762112 -0.246573 -0.592059 -0.997259
# 30 -3.242116 -2.029163 -1.509992  0.279883
# 40 -5.213249 -1.738298 -1.624639  1.098619
# 50 -5.721460 -1.841099 -3.329932  1.173175
# 60 -6.034304  0.124850 -4.005561  1.053858
# 70 -6.722393 -0.928499 -4.152564  0.394836
# 80 -7.533279  0.898410 -4.830924  0.121531
# 90 -7.257939  0.710855 -5.037964  0.847043

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## 柱状图

# %%
fig,axes=plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))

# %%
data
# Out:
# a    0.112070
# b    0.978261
# c    0.098449
# d    0.222083
# e    0.324506
# f    0.860544
# g    0.384452
# h    0.868237
# i    0.185831
# j    0.479325
# k    0.606985
# l    0.996912
# m    0.569942
# n    0.927469
# o    0.103305
# p    0.205851
# dtype: float64

# %%
data.plot(kind='bar',ax=axes[0],color='k',alpha=0.7)

# %%
data.plot(kind='barh',ax=axes[1],color='k',alpha=0.7)

# %%
df=pd.DataFrame(np.random.rand(6,4),
            index=['one','two','three','four','five','six'],
            columns=pd.Index(['A','B','C','D'],name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.091949  0.032610  0.723685  0.308071
# two    0.867809  0.926480  0.013285  0.993154
# three  0.100023  0.681116  0.920000  0.730270
# four   0.706097  0.109557  0.604787  0.675137
# five   0.640133  0.991444  0.531689  0.582355
# six    0.172561  0.923295  0.147983  0.835819

# %%
df.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df.plot(kind='barh',stacked=True,alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
s.value_counts().plot(kind='bar')

# %%
tips=pd.read_csv('/Users/liuxiaochi/Documents/PythonCode/Python_for_Data_Analysis/ch08/tips.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
party_counts=pd.crosstab(tips.day,tips.size)

# %%
party_counts
# Out:
# col_0  1708
# day
# Fri      19
# Sat      87
# Sun      76
# Thur     62

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')

# %%
large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")
# %matplotlib inline

# %%
print(mpl.__version__)  #> 3.0.0
print(sns.__version__)  #> 0.9.0
# Out:
# 2.2.2
# 0.9.0

# %% [markdown]
# # 时间序列

# %%
from datetime import datetime

# %%
now=datetime.now()

# %%
now
# Out:
# datetime.datetime(2019, 3, 21, 12, 37, 36, 722022)

# %%
now.year,now.month,now.day
# Out:
# (2019, 3, 21)

# %%
delta=datetime(2011,1,7)-datetime(2008,6,24,8,15)

# %%
delta
# Out:
# datetime.timedelta(926, 56700)

# %%
delta.days
# Out:
# 926

# %%
delta.seconds
# Out:
# 56700

# %%
stamp=datetime(2011,1,3)

# %%
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
stamp.strftime('%Y-%m-%d')
# Out:
# '2011-01-03'

# %%
from datetime import timedelta

# %%
start=datetime(2011,1,7)

# %%
start+timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start-2*timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %%
timedelta(12).months
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-4ea36cd67bb7> in <module>()
# ----> 1 timedelta(12).months
#
# AttributeError: 'datetime.timedelta' object has no attribute 'months'
